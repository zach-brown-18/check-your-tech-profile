# %% [markdown]
# # KNN Model

# %% [markdown]
# ## KNN description:
# Goes through the same steps as count vectorizer, but gathers the 75 most closely related job postings.
# Calculates the frequency of each job title in those 75 most related jobs.
# Job recommendation is then based on the most frequent job title of the 75 most closely related posts to the LinkedIn profile.

# %%
import pandas as pd
import numpy as np
import re
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from sklearn.neighbors import NearestNeighbors
from IPython.display import display_html

# %% [markdown]
# ## Jobs data

# %%
jobs = pd.read_csv('../data/job_postings.csv')
jobs = jobs.drop(columns=['date_added', 'organization', 'skills_len', 'job_type'])
jobs.fillna('', inplace=True)
jobs['text'] = jobs['job_description'] + ' ' + jobs['skills']

# %%
jobs
# Out:
#                                          job_description      job_title  \
# 0       n edi analyst with experience please read on ...        Analyst
# 1      informatica etl developerst petersburg fl only...      Developer
# 2      this nationally recognized microsoft gold part...        Manager
# 3       .net developer with experience please read on...      Developer
# 4      hatstand a global financial consultancy is see...      Developer
# ...                                                  ...            ...
# 16427   jpmorgan chase co. (nyse: jpm) is a leading g...      Developer
# 16428  seeking jr. systems administrators with experi...  Administrator
# 16429   senior lead devops engineer with a desired to...      Developer
# 16430  headquartered in downtown san francisco ca we ...      Developer
# 16431   n appsec or hardware security engineer who ha...       Engineer
#
#                       location  \
# 0      Northeast United States
# 1       Southern United States
# 2        Western United States
# 3      Northeast United States
# 4      Northeast United States
# ...                        ...
# 16427  Northeast United States
# 16428    Midwest United States
# 16429    Midwest United States
# 16430    Western United States
# 16431    Western United States
#
#                                                   skills  \
# 0                                 edi trustedlink as van
# 1      etl informatica b data exchange netezza oracle...
# 2      microsoft dynamics ax project manager - toront...
# 3                           c asp.net sql javascript mvc
# 4      java linux unix sdlc; multi-threaded or concur...
# ...                                                  ...
# 16427  .net architecture developer development git ht...
# 16428                            jr. linux administrator
# 16429   amazon web services linux bash ruby python agile
# 16430  javascript react.js golang startup ror iot ana...
# 16431  c .net java software application security hard...
#
#                                                     text
# 0       n edi analyst with experience please read on ...
# 1      informatica etl developerst petersburg fl only...
# 2      this nationally recognized microsoft gold part...
# 3       .net developer with experience please read on...
# 4      hatstand a global financial consultancy is see...
# ...                                                  ...
# 16427   jpmorgan chase co. (nyse: jpm) is a leading g...
# 16428  seeking jr. systems administrators with experi...
# 16429   senior lead devops engineer with a desired to...
# 16430  headquartered in downtown san francisco ca we ...
# 16431   n appsec or hardware security engineer who ha...
#
# [16432 rows x 5 columns]

# %% [markdown]
# ## User data

# %%
def gather_profile_data(file_path):
    profile_data = pd.read_csv(file_path)
    profile_data['text'] = profile_data['Titles'] + ' ' \
                            + profile_data['Skills'] + ' ' \
                            + profile_data['Summary'] + ' ' \
                            + profile_data['Education']
    try: profile_data['text'] += ' ' + profile_data['Certifications']
    except: pass
    
    try: profile_data['text'] += ' ' + profile_data['Projects']
    except: pass
    
    return profile_data

# %%
# Reading in linkedin profile data.
profile_data_zach = gather_profile_data('../data/linkedin/test-output/Zach_LinkedInData_12-16-2020.csv')
profile_data_nolan = gather_profile_data('../data/linkedin/test-output/Nolan_LinkedInData_12-16-2020.csv')
profile_data_albert = gather_profile_data('../data/linkedin/test-output/Albert_LinkedInData.csv')
profile_data_ye = gather_profile_data('../data/linkedin/test-output/Ye_LinkedInData.csv')

# %% [markdown]
# ## Make recommendations

# %%
def get_recommendations(vectorizer, tfidf_jobtext, user_data):
    # Transforming user profile text
    user_tfidf = vectorizer.transform(user_data['text'])

    # Calculating KNN similarity between users profile and job text (top 100 most similar jobs)
    n_neighbors=75
    KNN = NearestNeighbors(n_neighbors=n_neighbors, p=2, metric='cosine', algorithm = 'brute')
    KNN.fit(tfidf_jobtext)
    NNs = KNN.kneighbors(user_tfidf, return_distance=True)

    # Finding indexs for n_neighbors most similar jobs
    index = list(NNs[1][0][1:]) # indexs for top jobs
    final_jobs = jobs.loc[index] 
    
    # Create a dataframe using our job title counts(top 10)
    pos_df = pd.DataFrame(final_jobs['job_title'].value_counts()[:10])
    
    # Renaming job_title
    pos_df['Job Count'] = pos_df['job_title']
    pos_df.drop(columns='job_title', inplace= True)
    
    # Creating column for percent of jobs matched
    pos_df['Job Match %'] = pos_df['Job Count']/n_neighbors
    
    return pos_df

# %% [markdown]
# ## Specific Recommendations

# %%
# Instantiating Tfidfvectorizer
tfidf_vectorizer = TfidfVectorizer(stop_words='english', ngram_range=(1,2))
tfidf_jobtext = tfidf_vectorizer.fit_transform(jobs['text'])

# %%
# Calculate recommendations
nolans_recommendations = get_recommendations(tfidf_vectorizer, tfidf_jobtext, profile_data_nolan)
zachs_recommendations = get_recommendations(tfidf_vectorizer, tfidf_jobtext, profile_data_zach)
alberts_recommendations = get_recommendations(tfidf_vectorizer, tfidf_jobtext, profile_data_albert)
yes_recommendations = get_recommendations(tfidf_vectorizer, tfidf_jobtext, profile_data_ye)

# %%
# Credit for notebook styling: https://blog.softhints.com/display-two-pandas-dataframes-side-by-side-jupyter-notebook/
df1_styler = zachs_recommendations.style.set_table_attributes("style='display:inline'").set_caption('Zach')
df2_styler = nolans_recommendations.style.set_table_attributes("style='display:inline'").set_caption('Nolan')
df3_styler = alberts_recommendations.style.set_table_attributes("style='display:inline'").set_caption('Albert')
df4_styler = yes_recommendations.style.set_table_attributes("style='display:inline'").set_caption('Ye')

space = "\xa0" * 50
display_html(df1_styler._repr_html_() + space + df2_styler._repr_html_() + space + df3_styler._repr_html_() + space + df4_styler._repr_html_(), raw=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390a" style='display:inline'><caption>Zach</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Job Count</th>        <th class="col_heading level0 col1" >Job Match %</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390alevel0_row0" class="row_heading level0 row0" >Data Position</th>
#                         <td id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390arow0_col0" class="data row0 col0" >37</td>
#                         <td id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390arow0_col1" class="data row0 col1" >0.493333</td>
#             </tr>
#             <tr>
#                         <th id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390alevel0_row1" class="row_heading level0 row1" >Analyst</th>
#                         <td id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390arow1_col0" class="data row1 col0" >10</td>
#                         <td id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390arow1_col1" class="data row1 col1" >0.133333</td>
#             </tr>
#             <tr>
#                         <th id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390alevel0_row2" class="row_heading level0 row2" >Engineer</th>
#                         <td id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390arow2_col0" class="data row2 col0" >8</td>
#                         <td id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390arow2_col1" class="data row2 col1" >0.106667</td>
#             </tr>
#             <tr>
#                         <th id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390alevel0_row3" class="row_heading level0 row3" >Developer</th>
#                         <td id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390arow3_col0" class="data row3 col0" >7</td>
#                         <td id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390arow3_col1" class="data row3 col1" >0.093333</td>
#             </tr>
#             <tr>
#                         <th id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390alevel0_row4" class="row_heading level0 row4" >Architect</th>
#                         <td id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390arow4_col0" class="data row4 col0" >7</td>
#                         <td id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390arow4_col1" class="data row4 col1" >0.093333</td>
#             </tr>
#             <tr>
#                         <th id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390alevel0_row5" class="row_heading level0 row5" >Manager</th>
#                         <td id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390arow5_col0" class="data row5 col0" >2</td>
#                         <td id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390arow5_col1" class="data row5 col1" >0.026667</td>
#             </tr>
#             <tr>
#                         <th id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390alevel0_row6" class="row_heading level0 row6" >Director</th>
#                         <td id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390arow6_col0" class="data row6 col0" >1</td>
#                         <td id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390arow6_col1" class="data row6 col1" >0.013333</td>
#             </tr>
#             <tr>
#                         <th id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390alevel0_row7" class="row_heading level0 row7" >Programmer</th>
#                         <td id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390arow7_col0" class="data row7 col0" >1</td>
#                         <td id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390arow7_col1" class="data row7 col1" >0.013333</td>
#             </tr>
#             <tr>
#                         <th id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390alevel0_row8" class="row_heading level0 row8" >Consulting</th>
#                         <td id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390arow8_col0" class="data row8 col0" >1</td>
#                         <td id="T_e1106f0c_44b6_11eb_87fb_a4d18cca390arow8_col1" class="data row8 col1" >0.013333</td>
#             </tr>
#     </tbody></table>                                                  <style  type="text/css" >
# </style><table id="T_e110caec_44b6_11eb_87fb_a4d18cca390a" style='display:inline'><caption>Nolan</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Job Count</th>        <th class="col_heading level0 col1" >Job Match %</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e110caec_44b6_11eb_87fb_a4d18cca390alevel0_row0" class="row_heading level0 row0" >Data Position</th>
#                         <td id="T_e110caec_44b6_11eb_87fb_a4d18cca390arow0_col0" class="data row0 col0" >26</td>
#                         <td id="T_e110caec_44b6_11eb_87fb_a4d18cca390arow0_col1" class="data row0 col1" >0.346667</td>
#             </tr>
#             <tr>
#                         <th id="T_e110caec_44b6_11eb_87fb_a4d18cca390alevel0_row1" class="row_heading level0 row1" >Developer</th>
#                         <td id="T_e110caec_44b6_11eb_87fb_a4d18cca390arow1_col0" class="data row1 col0" >17</td>
#                         <td id="T_e110caec_44b6_11eb_87fb_a4d18cca390arow1_col1" class="data row1 col1" >0.226667</td>
#             </tr>
#             <tr>
#                         <th id="T_e110caec_44b6_11eb_87fb_a4d18cca390alevel0_row2" class="row_heading level0 row2" >Engineer</th>
#                         <td id="T_e110caec_44b6_11eb_87fb_a4d18cca390arow2_col0" class="data row2 col0" >11</td>
#                         <td id="T_e110caec_44b6_11eb_87fb_a4d18cca390arow2_col1" class="data row2 col1" >0.146667</td>
#             </tr>
#             <tr>
#                         <th id="T_e110caec_44b6_11eb_87fb_a4d18cca390alevel0_row3" class="row_heading level0 row3" >Architect</th>
#                         <td id="T_e110caec_44b6_11eb_87fb_a4d18cca390arow3_col0" class="data row3 col0" >10</td>
#                         <td id="T_e110caec_44b6_11eb_87fb_a4d18cca390arow3_col1" class="data row3 col1" >0.133333</td>
#             </tr>
#             <tr>
#                         <th id="T_e110caec_44b6_11eb_87fb_a4d18cca390alevel0_row4" class="row_heading level0 row4" >Analyst</th>
#                         <td id="T_e110caec_44b6_11eb_87fb_a4d18cca390arow4_col0" class="data row4 col0" >5</td>
#                         <td id="T_e110caec_44b6_11eb_87fb_a4d18cca390arow4_col1" class="data row4 col1" >0.066667</td>
#             </tr>
#             <tr>
#                         <th id="T_e110caec_44b6_11eb_87fb_a4d18cca390alevel0_row5" class="row_heading level0 row5" >Consulting</th>
#                         <td id="T_e110caec_44b6_11eb_87fb_a4d18cca390arow5_col0" class="data row5 col0" >3</td>
#                         <td id="T_e110caec_44b6_11eb_87fb_a4d18cca390arow5_col1" class="data row5 col1" >0.040000</td>
#             </tr>
#             <tr>
#                         <th id="T_e110caec_44b6_11eb_87fb_a4d18cca390alevel0_row6" class="row_heading level0 row6" >Director</th>
#                         <td id="T_e110caec_44b6_11eb_87fb_a4d18cca390arow6_col0" class="data row6 col0" >1</td>
#                         <td id="T_e110caec_44b6_11eb_87fb_a4d18cca390arow6_col1" class="data row6 col1" >0.013333</td>
#             </tr>
#             <tr>
#                         <th id="T_e110caec_44b6_11eb_87fb_a4d18cca390alevel0_row7" class="row_heading level0 row7" >Manager</th>
#                         <td id="T_e110caec_44b6_11eb_87fb_a4d18cca390arow7_col0" class="data row7 col0" >1</td>
#                         <td id="T_e110caec_44b6_11eb_87fb_a4d18cca390arow7_col1" class="data row7 col1" >0.013333</td>
#             </tr>
#     </tbody></table>                                                  <style  type="text/css" >
# </style><table id="T_e1113b9e_44b6_11eb_87fb_a4d18cca390a" style='display:inline'><caption>Albert</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Job Count</th>        <th class="col_heading level0 col1" >Job Match %</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e1113b9e_44b6_11eb_87fb_a4d18cca390alevel0_row0" c

# %% [markdown]
# ## KNN Conclusion
# Most common job matches appear to line up with what we would expect. Albert, Nolan and Zach were all recommended Data positions while Ye was recommended a Developer position.
# Job match % may not be the most useful metric to compare other models to but it does give a sense of how well we can trust our given job output.
# KNN is also influenced by the balance of job titles and data positions was by far one of the least common. Yet, we still got recommended data positions which shows some strength to this model.
