# %% [markdown]
# # CountVectorizer Model

# %%
import pandas as pd
import numpy as np
import re
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from IPython.display import display_html

# %% [markdown]
# ## Jobs data

# %%
jobs = pd.read_csv('../data/job_postings.csv')
jobs = jobs.drop(columns=['date_added', 'organization', 'skills_len', 'job_type'])
jobs.fillna('', inplace=True)
jobs['text'] = jobs['job_description'] + ' ' + jobs['skills']

# %% [markdown]
# ## User data

# %%
def gather_profile_data(file_path):
    profile_data = pd.read_csv(file_path)
    profile_data['text'] = profile_data['Titles'] + ' ' \
                            + profile_data['Skills'] + ' ' \
                            + profile_data['Summary'] + ' ' \
                            + profile_data['Education']
    return profile_data

# %%
# Reading in Zach's linkedin profile data.
profile_data_zach = gather_profile_data('../data/linkedin/test-output/Zach_LinkedInData_12-16-2020.csv')
profile_data_zach
# Out:
#             Name                                             Titles  \
# 0  zachary brown  data science fellow  python developer  health ...
#
#                                               Skills  \
# 0  data analysis  python (programming language)  ...
#
#                                              Summary  \
# 0  i bridge the gap between data and climate poli...
#
#                                        Education  \
# 0  data science intensive  bachelor's of science
#
#                                       Certifications  \
# 0  microsoft certified: azure data scientist asso...
#
#                                                 text
# 0  data science fellow  python developer  health ...

# %%
# Reading in Nolan's linkedin profile data.
profile_data_nolan = gather_profile_data('../data/linkedin/test-output/Nolan_LinkedInData_12-16-2020.csv')
profile_data_nolan
# Out:
#            Name                        Titles  \
# 0  nolan arendt  data science fellow  painter
#
#                                               Skills  \
# 0  data science  python  data analysis  data mana...
#
#                                              Summary  \
# 0  an innovative data scientist who is passionate...
#
#                                            Education  \
# 0  bachelor's degree  software boot camp certificate
#
#                                                 text
# 0  data science fellow  painter data science  pyt...

# %%
# Reading in Albert's linkedin profile data.
profile_data_albert = gather_profile_data('../data/linkedin/test-output/Albert_LinkedInData.csv')
profile_data_albert
# Out:
#             Name                                             Titles  \
# 0  albert frantz  data science fellow  assistant teacher  classr...
#
#                                               Skills  \
# 0  r  python  data analysis  econometrics  projec...
#
#                                              Summary  \
# 0  i am a detail-oriented data scientist that use...
#
#                          Education  \
# 0  bachelor of arts - ba  nan  nan
#
#                                             Projects  \
# 0  identifying the relationship between bike lane...
#
#                                       Certifications  \
# 0  tableau      a-z: hands-on tableau training fo...
#
#                                                 text
# 0  data science fellow  assistant teacher  classr...

# %% [markdown]
# ## Make recommendations

# %%
def get_recommendations(vectorizer, user_data):
    # Fit transform on text data
    cvec_jobtext = vectorizer.fit_transform(jobs['text'])

    # Transforming user profile text
    user_cvec = vectorizer.transform(user_data['text'])

    # Calculating cosine similarity between users profile and job text
    cos_similar_user = map(lambda x: cosine_similarity(user_cvec, x), cvec_jobtext)

    # Results are a list of our cosine similarity scores
    results = list(cos_similar_user)

    # Create a dataframe using our results and job_titles
    new_df = pd.DataFrame(data = [results, jobs['job_title']]).T
    new_df = new_df.rename(columns = {0: "sim_score", 1 : "job_title"})

    # Column sim_score as float so that we can use groupby
    new_df['sim_score'] = new_df['sim_score'].astype(float)

    # Group by job_title, using count and mean to sort values
    new_df = new_df.groupby('job_title').agg(['count', 'mean'])['sim_score'].sort_values('mean', ascending=False)
    new_df = new_df.sort_values(by=['mean'], ascending = False)

    return new_df

# %%
# Instantiating countvectorizer
count_vectorizer = CountVectorizer()

# Instantiating countvectorizer with stopwords and min_df
count_vectorizer_stopwords = CountVectorizer(stop_words = "english", min_df = 10)

# %%
# Keep all words
zachs_recommendations = get_recommendations(count_vectorizer, profile_data_zach)
nolans_recommendations = get_recommendations(count_vectorizer, profile_data_nolan)
alberts_recommendations = get_recommendations(count_vectorizer, profile_data_albert)

# Remove stop words and min_df = 10
zachs_recommendations_stopwords = get_recommendations(count_vectorizer_stopwords, profile_data_zach)
nolans_recommendations_stopwords = get_recommendations(count_vectorizer_stopwords, profile_data_nolan)
alberts_recommendations_stopwords = get_recommendations(count_vectorizer_stopwords, profile_data_albert)

# %% [markdown]
# ### Zach

# %%
# Credit for notebook styling: https://blog.softhints.com/display-two-pandas-dataframes-side-by-side-jupyter-notebook/
df1_styler = zachs_recommendations.style.set_table_attributes("style='display:inline'").set_caption('All Words')
df2_styler = zachs_recommendations_stopwords.style.set_table_attributes("style='display:inline'").set_caption('Stopwords Removed')

space = "\xa0" * 10
display_html(df1_styler._repr_html_() + space + df2_styler._repr_html_(), raw=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390a" style='display:inline'><caption>All Words</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>    </tr>    <tr>        <th class="index_name level0" >job_title</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390alevel0_row0" class="row_heading level0 row0" >Data Position</th>
#                         <td id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390arow0_col0" class="data row0 col0" >280</td>
#                         <td id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390arow0_col1" class="data row0 col1" >0.367674</td>
#             </tr>
#             <tr>
#                         <th id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390alevel0_row1" class="row_heading level0 row1" >Analyst</th>
#                         <td id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390arow1_col0" class="data row1 col0" >1884</td>
#                         <td id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390arow1_col1" class="data row1 col1" >0.339164</td>
#             </tr>
#             <tr>
#                         <th id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390alevel0_row2" class="row_heading level0 row2" >Director</th>
#                         <td id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390arow2_col0" class="data row2 col0" >144</td>
#                         <td id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390arow2_col1" class="data row2 col1" >0.328041</td>
#             </tr>
#             <tr>
#                         <th id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390alevel0_row3" class="row_heading level0 row3" >Architect</th>
#                         <td id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390arow3_col0" class="data row3 col0" >823</td>
#                         <td id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390arow3_col1" class="data row3 col1" >0.323953</td>
#             </tr>
#             <tr>
#                         <th id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390alevel0_row4" class="row_heading level0 row4" >Manager</th>
#                         <td id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390arow4_col0" class="data row4 col0" >1379</td>
#                         <td id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390arow4_col1" class="data row4 col1" >0.305963</td>
#             </tr>
#             <tr>
#                         <th id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390alevel0_row5" class="row_heading level0 row5" >Engineer</th>
#                         <td id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390arow5_col0" class="data row5 col0" >4044</td>
#                         <td id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390arow5_col1" class="data row5 col1" >0.304451</td>
#             </tr>
#             <tr>
#                         <th id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390alevel0_row6" class="row_heading level0 row6" >Administrator</th>
#                         <td id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390arow6_col0" class="data row6 col0" >896</td>
#                         <td id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390arow6_col1" class="data row6 col1" >0.303012</td>
#             </tr>
#             <tr>
#                         <th id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390alevel0_row7" class="row_heading level0 row7" >Technician</th>
#                         <td id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390arow7_col0" class="data row7 col0" >342</td>
#                         <td id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390arow7_col1" class="data row7 col1" >0.301906</td>
#             </tr>
#             <tr>
#                         <th id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390alevel0_row8" class="row_heading level0 row8" >Support</th>
#                         <td id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390arow8_col0" class="data row8 col0" >342</td>
#                         <td id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390arow8_col1" class="data row8 col1" >0.294115</td>
#             </tr>
#             <tr>
#                         <th id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390alevel0_row9" class="row_heading level0 row9" >Developer</th>
#                         <td id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390arow9_col0" class="data row9 col0" >5179</td>
#                         <td id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390arow9_col1" class="data row9 col1" >0.293118</td>
#             </tr>
#             <tr>
#                         <th id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390alevel0_row10" class="row_heading level0 row10" >Programmer</th>
#                         <td id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390arow10_col0" class="data row10 col0" >321</td>
#                         <td id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390arow10_col1" class="data row10 col1" >0.290833</td>
#             </tr>
#             <tr>
#                         <th id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390alevel0_row11" class="row_heading level0 row11" >Designer</th>
#                         <td id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390arow11_col0" class="data row11 col0" >220</td>
#                         <td id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390arow11_col1" class="data row11 col1" >0.279332</td>
#             </tr>
#             <tr>
#                         <th id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390alevel0_row12" class="row_heading level0 row12" >Consulting</th>
#                         <td id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390arow12_col0" class="data row12 col0" >578</td>
#                         <td id="T_83a0a93e_43b9_11eb_8c1a_a4d18cca390arow12_col1" class="data row12 col1" >0.265805</td>
#             </tr>
#     </tbody></table>          <style  type="text/css" >
# </style><table id="T_83a1026c_43b9_11eb_8c1a_a4d18cca390a" style='display:inline'><caption>Stopwords Removed</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>    </tr>    <tr>        <th class="index_name level0" >job_title</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_83a1026c_43b9_11eb_8c1a_a4d18cca390alevel0_row0" class="row_heading level0 row0" >Data Position</th>
#                         <td id="T_83a1026c_43b9_11eb_8c1a_a4d18cca390arow0_col0" class="data row0 col0" >280</td>
#                         <td id="T_83a1026c_43b9_11eb_8c1a_a4d18cca390arow0_col1" class="data row0 col1" >0.179976</td>
#             </tr>
#             <tr>
#                         <th id="T_83a1026c_43b9_11eb_8c1a_a4d18cca390alevel0_row1" class="row_heading level0 row1" >Analyst</th>
#                         <td id="T_83a1026c_43b9_11eb_8c1a_a4d18cca390arow1_col0" class="data row1 col0" >1884</td>
#                         <td id="T_83a1026c_43b9_11eb_8c1a_a4d18cca390arow1_col1" class="data row1 col1" >0.127517</td>
#             </tr>
#             <tr>
#                         <th id="T_83a1026c_43b9_11eb_8c1a_a4d18cca390alevel0_row2" class="row_heading level0 row2" >Architect</th>
#                         <td id="T_83a1026c_43b9_11eb_8c1a_a4d18cca390arow2_col0" class="data row2 col0" >823</td>
#                         <td id="T_83a1026c_43b9_11eb_8c1a_a4d18cca390arow2_col1" class="data row2 col1" >0.127388</td>
#             </tr>
#             <tr>
#                         <th id="T_83a1026c_43b9_11eb_8c1a_a4d18cca390alevel0_row3" class="row_heading level0 row3" >Developer</th>
#                         <td id="T_83a1026c_43b9_11eb_8c1a_a4d18cca390arow3_col0" class="data row3 col0" >5179</td>
#                         <td id="T_83a1026c_43b9_11eb_8c1a_a4d18cca390arow3_col1" class="data row3 col1" >0.096288</td>
#             </tr>
#             <tr>
#                         <th id="T_83a1026c_43b9_11eb_8c1a_a4d18cca390alevel0_row4" class="row_heading level0 row4" >Director</th>
#                         <td id="T_83a1026c_43b9_11eb_8c1a_a4d18cca390arow4_col0"

# %% [markdown]
# ### Nolan

# %%
df1_styler = nolans_recommendations.style.set_table_attributes("style='display:inline'").set_caption('All Words')
df2_styler = nolans_recommendations_stopwords.style.set_table_attributes("style='display:inline'").set_caption('Stopwords Removed')

space = "\xa0" * 10
display_html(df1_styler._repr_html_() + space + df2_styler._repr_html_(), raw=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_83a29122_43b9_11eb_8c1a_a4d18cca390a" style='display:inline'><caption>All Words</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>    </tr>    <tr>        <th class="index_name level0" >job_title</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_83a29122_43b9_11eb_8c1a_a4d18cca390alevel0_row0" class="row_heading level0 row0" >Data Position</th>
#                         <td id="T_83a29122_43b9_11eb_8c1a_a4d18cca390arow0_col0" class="data row0 col0" >280</td>
#                         <td id="T_83a29122_43b9_11eb_8c1a_a4d18cca390arow0_col1" class="data row0 col1" >0.193067</td>
#             </tr>
#             <tr>
#                         <th id="T_83a29122_43b9_11eb_8c1a_a4d18cca390alevel0_row1" class="row_heading level0 row1" >Analyst</th>
#                         <td id="T_83a29122_43b9_11eb_8c1a_a4d18cca390arow1_col0" class="data row1 col0" >1884</td>
#                         <td id="T_83a29122_43b9_11eb_8c1a_a4d18cca390arow1_col1" class="data row1 col1" >0.166393</td>
#             </tr>
#             <tr>
#                         <th id="T_83a29122_43b9_11eb_8c1a_a4d18cca390alevel0_row2" class="row_heading level0 row2" >Architect</th>
#                         <td id="T_83a29122_43b9_11eb_8c1a_a4d18cca390arow2_col0" class="data row2 col0" >823</td>
#                         <td id="T_83a29122_43b9_11eb_8c1a_a4d18cca390arow2_col1" class="data row2 col1" >0.162124</td>
#             </tr>
#             <tr>
#                         <th id="T_83a29122_43b9_11eb_8c1a_a4d18cca390alevel0_row3" class="row_heading level0 row3" >Developer</th>
#                         <td id="T_83a29122_43b9_11eb_8c1a_a4d18cca390arow3_col0" class="data row3 col0" >5179</td>
#                         <td id="T_83a29122_43b9_11eb_8c1a_a4d18cca390arow3_col1" class="data row3 col1" >0.150255</td>
#             </tr>
#             <tr>
#                         <th id="T_83a29122_43b9_11eb_8c1a_a4d18cca390alevel0_row4" class="row_heading level0 row4" >Director</th>
#                         <td id="T_83a29122_43b9_11eb_8c1a_a4d18cca390arow4_col0" class="data row4 col0" >144</td>
#                         <td id="T_83a29122_43b9_11eb_8c1a_a4d18cca390arow4_col1" class="data row4 col1" >0.146972</td>
#             </tr>
#             <tr>
#                         <th id="T_83a29122_43b9_11eb_8c1a_a4d18cca390alevel0_row5" class="row_heading level0 row5" >Programmer</th>
#                         <td id="T_83a29122_43b9_11eb_8c1a_a4d18cca390arow5_col0" class="data row5 col0" >321</td>
#                         <td id="T_83a29122_43b9_11eb_8c1a_a4d18cca390arow5_col1" class="data row5 col1" >0.146852</td>
#             </tr>
#             <tr>
#                         <th id="T_83a29122_43b9_11eb_8c1a_a4d18cca390alevel0_row6" class="row_heading level0 row6" >Engineer</th>
#                         <td id="T_83a29122_43b9_11eb_8c1a_a4d18cca390arow6_col0" class="data row6 col0" >4044</td>
#                         <td id="T_83a29122_43b9_11eb_8c1a_a4d18cca390arow6_col1" class="data row6 col1" >0.139270</td>
#             </tr>
#             <tr>
#                         <th id="T_83a29122_43b9_11eb_8c1a_a4d18cca390alevel0_row7" class="row_heading level0 row7" >Administrator</th>
#                         <td id="T_83a29122_43b9_11eb_8c1a_a4d18cca390arow7_col0" class="data row7 col0" >896</td>
#                         <td id="T_83a29122_43b9_11eb_8c1a_a4d18cca390arow7_col1" class="data row7 col1" >0.137523</td>
#             </tr>
#             <tr>
#                         <th id="T_83a29122_43b9_11eb_8c1a_a4d18cca390alevel0_row8" class="row_heading level0 row8" >Manager</th>
#                         <td id="T_83a29122_43b9_11eb_8c1a_a4d18cca390arow8_col0" class="data row8 col0" >1379</td>
#                         <td id="T_83a29122_43b9_11eb_8c1a_a4d18cca390arow8_col1" class="data row8 col1" >0.136588</td>
#             </tr>
#             <tr>
#                         <th id="T_83a29122_43b9_11eb_8c1a_a4d18cca390alevel0_row9" class="row_heading level0 row9" >Consulting</th>
#                         <td id="T_83a29122_43b9_11eb_8c1a_a4d18cca390arow9_col0" class="data row9 col0" >578</td>
#                         <td id="T_83a29122_43b9_11eb_8c1a_a4d18cca390arow9_col1" class="data row9 col1" >0.129598</td>
#             </tr>
#             <tr>
#                         <th id="T_83a29122_43b9_11eb_8c1a_a4d18cca390alevel0_row10" class="row_heading level0 row10" >Support</th>
#                         <td id="T_83a29122_43b9_11eb_8c1a_a4d18cca390arow10_col0" class="data row10 col0" >342</td>
#                         <td id="T_83a29122_43b9_11eb_8c1a_a4d18cca390arow10_col1" class="data row10 col1" >0.123708</td>
#             </tr>
#             <tr>
#                         <th id="T_83a29122_43b9_11eb_8c1a_a4d18cca390alevel0_row11" class="row_heading level0 row11" >Designer</th>
#                         <td id="T_83a29122_43b9_11eb_8c1a_a4d18cca390arow11_col0" class="data row11 col0" >220</td>
#                         <td id="T_83a29122_43b9_11eb_8c1a_a4d18cca390arow11_col1" class="data row11 col1" >0.121607</td>
#             </tr>
#             <tr>
#                         <th id="T_83a29122_43b9_11eb_8c1a_a4d18cca390alevel0_row12" class="row_heading level0 row12" >Technician</th>
#                         <td id="T_83a29122_43b9_11eb_8c1a_a4d18cca390arow12_col0" class="data row12 col0" >342</td>
#                         <td id="T_83a29122_43b9_11eb_8c1a_a4d18cca390arow12_col1" class="data row12 col1" >0.114109</td>
#             </tr>
#     </tbody></table>          <style  type="text/css" >
# </style><table id="T_83a2f81a_43b9_11eb_8c1a_a4d18cca390a" style='display:inline'><caption>Stopwords Removed</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>    </tr>    <tr>        <th class="index_name level0" >job_title</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_83a2f81a_43b9_11eb_8c1a_a4d18cca390alevel0_row0" class="row_heading level0 row0" >Data Position</th>
#                         <td id="T_83a2f81a_43b9_11eb_8c1a_a4d18cca390arow0_col0" class="data row0 col0" >280</td>
#                         <td id="T_83a2f81a_43b9_11eb_8c1a_a4d18cca390arow0_col1" class="data row0 col1" >0.205967</td>
#             </tr>
#             <tr>
#                         <th id="T_83a2f81a_43b9_11eb_8c1a_a4d18cca390alevel0_row1" class="row_heading level0 row1" >Analyst</th>
#                         <td id="T_83a2f81a_43b9_11eb_8c1a_a4d18cca390arow1_col0" class="data row1 col0" >1884</td>
#                         <td id="T_83a2f81a_43b9_11eb_8c1a_a4d18cca390arow1_col1" class="data row1 col1" >0.156924</td>
#             </tr>
#             <tr>
#                         <th id="T_83a2f81a_43b9_11eb_8c1a_a4d18cca390alevel0_row2" class="row_heading level0 row2" >Architect</th>
#                         <td id="T_83a2f81a_43b9_11eb_8c1a_a4d18cca390arow2_col0" class="data row2 col0" >823</td>
#                         <td id="T_83a2f81a_43b9_11eb_8c1a_a4d18cca390arow2_col1" class="data row2 col1" >0.147545</td>
#             </tr>
#             <tr>
#                         <th id="T_83a2f81a_43b9_11eb_8c1a_a4d18cca390alevel0_row3" class="row_heading level0 row3" >Director</th>
#                         <td id="T_83a2f81a_43b9_11eb_8c1a_a4d18cca390arow3_col0" class="data row3 col0" >144</td>
#                         <td id="T_83a2f81a_43b9_11eb_8c1a_a4d18cca390arow3_col1" class="data row3 col1" >0.130016</td>
#             </tr>
#             <tr>
#                         <th id="T_83a2f81a_43b9_11eb_8c1a_a4d18cca390alevel0_row4" class="row_heading level0 row4" >Developer</th>
#                         <td id="T_83a2f81a_43b9_11eb_8c1a_a4d18cca390arow4_col0"

# %% [markdown]
# ### Albert

# %%
df1_styler = alberts_recommendations.style.set_table_attributes("style='display:inline'").set_caption('All Words')
df2_styler = alberts_recommendations_stopwords.style.set_table_attributes("style='display:inline'").set_caption('Stopwords Removed')

space = "\xa0" * 10
display_html(df1_styler._repr_html_() + space + df2_styler._repr_html_(), raw=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390a" style='display:inline'><caption>All Words</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>    </tr>    <tr>        <th class="index_name level0" >job_title</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390alevel0_row0" class="row_heading level0 row0" >Data Position</th>
#                         <td id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390arow0_col0" class="data row0 col0" >280</td>
#                         <td id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390arow0_col1" class="data row0 col1" >0.397163</td>
#             </tr>
#             <tr>
#                         <th id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390alevel0_row1" class="row_heading level0 row1" >Director</th>
#                         <td id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390arow1_col0" class="data row1 col0" >144</td>
#                         <td id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390arow1_col1" class="data row1 col1" >0.367056</td>
#             </tr>
#             <tr>
#                         <th id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390alevel0_row2" class="row_heading level0 row2" >Analyst</th>
#                         <td id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390arow2_col0" class="data row2 col0" >1884</td>
#                         <td id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390arow2_col1" class="data row2 col1" >0.366224</td>
#             </tr>
#             <tr>
#                         <th id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390alevel0_row3" class="row_heading level0 row3" >Architect</th>
#                         <td id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390arow3_col0" class="data row3 col0" >823</td>
#                         <td id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390arow3_col1" class="data row3 col1" >0.359621</td>
#             </tr>
#             <tr>
#                         <th id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390alevel0_row4" class="row_heading level0 row4" >Manager</th>
#                         <td id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390arow4_col0" class="data row4 col0" >1379</td>
#                         <td id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390arow4_col1" class="data row4 col1" >0.354180</td>
#             </tr>
#             <tr>
#                         <th id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390alevel0_row5" class="row_heading level0 row5" >Engineer</th>
#                         <td id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390arow5_col0" class="data row5 col0" >4044</td>
#                         <td id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390arow5_col1" class="data row5 col1" >0.343097</td>
#             </tr>
#             <tr>
#                         <th id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390alevel0_row6" class="row_heading level0 row6" >Programmer</th>
#                         <td id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390arow6_col0" class="data row6 col0" >321</td>
#                         <td id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390arow6_col1" class="data row6 col1" >0.332967</td>
#             </tr>
#             <tr>
#                         <th id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390alevel0_row7" class="row_heading level0 row7" >Developer</th>
#                         <td id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390arow7_col0" class="data row7 col0" >5179</td>
#                         <td id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390arow7_col1" class="data row7 col1" >0.331946</td>
#             </tr>
#             <tr>
#                         <th id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390alevel0_row8" class="row_heading level0 row8" >Technician</th>
#                         <td id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390arow8_col0" class="data row8 col0" >342</td>
#                         <td id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390arow8_col1" class="data row8 col1" >0.327459</td>
#             </tr>
#             <tr>
#                         <th id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390alevel0_row9" class="row_heading level0 row9" >Designer</th>
#                         <td id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390arow9_col0" class="data row9 col0" >220</td>
#                         <td id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390arow9_col1" class="data row9 col1" >0.326477</td>
#             </tr>
#             <tr>
#                         <th id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390alevel0_row10" class="row_heading level0 row10" >Support</th>
#                         <td id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390arow10_col0" class="data row10 col0" >342</td>
#                         <td id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390arow10_col1" class="data row10 col1" >0.325237</td>
#             </tr>
#             <tr>
#                         <th id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390alevel0_row11" class="row_heading level0 row11" >Administrator</th>
#                         <td id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390arow11_col0" class="data row11 col0" >896</td>
#                         <td id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390arow11_col1" class="data row11 col1" >0.321535</td>
#             </tr>
#             <tr>
#                         <th id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390alevel0_row12" class="row_heading level0 row12" >Consulting</th>
#                         <td id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390arow12_col0" class="data row12 col0" >578</td>
#                         <td id="T_83a55bbe_43b9_11eb_8c1a_a4d18cca390arow12_col1" class="data row12 col1" >0.309706</td>
#             </tr>
#     </tbody></table>          <style  type="text/css" >
# </style><table id="T_83a5f3f8_43b9_11eb_8c1a_a4d18cca390a" style='display:inline'><caption>Stopwords Removed</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>    </tr>    <tr>        <th class="index_name level0" >job_title</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_83a5f3f8_43b9_11eb_8c1a_a4d18cca390alevel0_row0" class="row_heading level0 row0" >Data Position</th>
#                         <td id="T_83a5f3f8_43b9_11eb_8c1a_a4d18cca390arow0_col0" class="data row0 col0" >280</td>
#                         <td id="T_83a5f3f8_43b9_11eb_8c1a_a4d18cca390arow0_col1" class="data row0 col1" >0.215950</td>
#             </tr>
#             <tr>
#                         <th id="T_83a5f3f8_43b9_11eb_8c1a_a4d18cca390alevel0_row1" class="row_heading level0 row1" >Architect</th>
#                         <td id="T_83a5f3f8_43b9_11eb_8c1a_a4d18cca390arow1_col0" class="data row1 col0" >823</td>
#                         <td id="T_83a5f3f8_43b9_11eb_8c1a_a4d18cca390arow1_col1" class="data row1 col1" >0.161085</td>
#             </tr>
#             <tr>
#                         <th id="T_83a5f3f8_43b9_11eb_8c1a_a4d18cca390alevel0_row2" class="row_heading level0 row2" >Analyst</th>
#                         <td id="T_83a5f3f8_43b9_11eb_8c1a_a4d18cca390arow2_col0" class="data row2 col0" >1884</td>
#                         <td id="T_83a5f3f8_43b9_11eb_8c1a_a4d18cca390arow2_col1" class="data row2 col1" >0.160216</td>
#             </tr>
#             <tr>
#                         <th id="T_83a5f3f8_43b9_11eb_8c1a_a4d18cca390alevel0_row3" class="row_heading level0 row3" >Director</th>
#                         <td id="T_83a5f3f8_43b9_11eb_8c1a_a4d18cca390arow3_col0" class="data row3 col0" >144</td>
#                         <td id="T_83a5f3f8_43b9_11eb_8c1a_a4d18cca390arow3_col1" class="data row3 col1" >0.138401</td>
#             </tr>
#             <tr>
#                         <th id="T_83a5f3f8_43b9_11eb_8c1a_a4d18cca390alevel0_row4" class="row_heading level0 row4" >Manager</th>
#                         <td id="T_83a5f3f8_43b9_11eb_8c1a_a4d18cca390arow4_col0" cl
