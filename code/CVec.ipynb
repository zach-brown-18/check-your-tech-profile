# %% [markdown]
# # CountVectorizer Model

# %%
import pandas as pd
import numpy as np
import re
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity

# %%
# Reading in Jobs data
jobs = pd.read_csv('../data/job_postings.csv')
# Dropping unecessary columns from jobs
jobs = jobs.drop(columns=['date_added', 'organization', 'skills_len', 'job_type'])

# %%
# Replace nan's with empty string
jobs.fillna('', inplace=True)

# %%
# Combine job description and text into a single column
jobs['text'] = jobs['job_description'] + ' ' + jobs['skills']

# %%
# Reading in Zachs linkedin profile data.
profile_data_zach = pd.read_csv('../data/linkedin/test-output/Zach_LinkedInData_12-16-2020.csv')

# Creating one column, 'text' including titles, skills, summary, and education
profile_data_zach['text'] = profile_data_zach['Titles'] + ' ' \
                        + profile_data_zach['Skills'] + ' ' \
                        + profile_data_zach['Summary'] + ' ' \
                        + profile_data_zach['Education']
profile_data_zach
# Out:
#             Name                                             Titles  \
# 0  Zachary Brown  Data Science Fellow, Python Developer, Health ...
#
#                                               Skills  \
# 0  Data Analysis, Python (Programming Language), ...
#
#                                              Summary  \
# 0  I bridge the gap between data and climate poli...
#
#                                        Education  \
# 0  Data Science Intensive, Bachelor's of Science
#
#                                       Certifications  \
# 0  Microsoft Certified: Azure Data Scientist Asso...
#
#                                                 text
# 0  Data Science Fellow, Python Developer, Health ...

# %%
profile_data_nolan = pd.read_csv('../data/linkedin/test-output/Nolan_LinkedInData_12-16-2020.csv')

profile_data_nolan['text'] = profile_data_nolan['Titles'] + ' ' \
                        + profile_data_nolan['Skills'] + ' ' \
                        + profile_data_nolan['Summary'] + ' ' \
                        + profile_data_nolan['Education']
profile_data_nolan
# Out:
#            Name                        Titles  \
# 0  Nolan Arendt  Data Science Fellow, Painter
#
#                                               Skills  \
# 0  Data Science, Python, Data Analysis, Data Mana...
#
#                                              Summary  \
# 0  An innovative Data Scientist who is passionate...
#
#                                            Education  \
# 0  Bachelor's degree, Software Boot Camp Certificate
#
#                                                 text
# 0  Data Science Fellow, Painter Data Science, Pyt...

# %%
# Instantiating countvectorizer
count_vectorizer = CountVectorizer()

# Cvec fit transform on column text in data
cvec_jobtext = count_vectorizer.fit_transform(jobs['text'])

# Transforming user profile column text
user_cvec = count_vectorizer.transform(profile_data_zach['text'])

# Calculating cosine similarity between users profile and job text
cos_similar_user = map(lambda x: cosine_similarity(user_cvec, x), cvec_jobtext)

# Results are a list of our cosine similarity scores
results = list(cos_similar_user)

# Create a dataframe using our results and job_titles, then transposing
new_df = pd.DataFrame(data = [results, jobs['job_title']]).T
# Renaming column 0 to sim score, similar to our tfidf model, and 1 to job_title
new_df = new_df.rename(columns = {0: "sim_score", 1 : "job_title"})
# Column sim_score as float so that we can use groupby
new_df['sim_score'] = new_df['sim_score'].astype(float)
# Group by job_title, using count and mean to sort values
new_df = new_df.groupby('job_title').agg(['count', 'mean'])['sim_score'].sort_values('mean', ascending=False)
# Sorting our dataframe by mean, looking at either top 10 or top 3.
new_df = new_df.sort_values(by=['mean'], ascending = False)

new_df[0:10]
# Out:
#                count      mean
# job_title
# Data Position    282  0.363520
# Analyst         1892  0.338986
# Director         146  0.331122
# Architect        828  0.324737
# Engineer        4061  0.311045
# Manager         1389  0.307296
# Administrator    898  0.303593
# Technician       342  0.302790
# Programmer       321  0.297358
# Developer       5234  0.296042

# %%
# Instantiating countvectorizer
count_vectorizer = CountVectorizer(stop_words = "english", min_df = 10)

# Cvec fit transform on column text in data
cvec_jobtext = count_vectorizer.fit_transform(jobs['text'])

# Transforming user profile column text
user_cvec = count_vectorizer.transform(profile_data_zach['text'])
# Calculating cosine similarity between users profile and job text
cos_similar_user = map(lambda x: cosine_similarity(user_cvec, x), cvec_jobtext)

# Results are a list of our cosine similarity scores
results = list(cos_similar_user)

# Create a dataframe using our results and job_titles, then transposing
new_df = pd.DataFrame(data = [results, jobs['job_title']]).T
# Renaming column 0 to sim score, similar to our tfidf model, and 1 to job_title
new_df = new_df.rename(columns = {0: "sim_score", 1 : "job_title"})
# Column sim_score as float so that we can use groupby
new_df['sim_score'] = new_df['sim_score'].astype(float)
# Group by job_title, using count and mean to sort values
new_df = new_df.groupby('job_title').agg(['count', 'mean'])['sim_score'].sort_values('mean', ascending=False)
# Sorting our dataframe by mean, looking at either top 10 or top 3.
new_df = new_df.sort_values(by=['mean'], ascending = False)

new_df[0:10]
# Out:
#                count      mean
# job_title
# Data Position    282  0.174758
# Analyst         1892  0.126635
# Architect        828  0.126269
# Developer       5234  0.094536
# Director         146  0.091531
# Programmer       321  0.091021
# Engineer        4061  0.077693
# Administrator    898  0.073294
# Consulting       592  0.070977
# Manager         1389  0.064263

# %%
# Instantiating countvectorizer
count_vectorizer = CountVectorizer()

# Cvec fit transform on column text in data
cvec_jobtext = count_vectorizer.fit_transform((jobs['text']))

# Transforming user profile column text
user_cvec = count_vectorizer.transform(profile_data_nolan['text'])
# Calculating cosine similarity between users profile and job text
cos_similar_user = map(lambda x: cosine_similarity(user_cvec, x), cvec_jobtext)

# Results are a list of our cosine similarity scores
results = list(cos_similar_user)

# Create a dataframe using our results and job_titles, then transposing
new_df = pd.DataFrame(data = [results, jobs['job_title']]).T
# Renaming column 0 to sim score, similar to our tfidf model, and 1 to job_title
new_df = new_df.rename(columns = {0: "sim_score", 1 : "job_title"})
# Column sim_score as float so that we can use groupby
new_df['sim_score'] = new_df['sim_score'].astype(float)
# Group by job_title, using count and mean to sort values
new_df = new_df.groupby('job_title').agg(['count', 'mean'])['sim_score'].sort_values('mean', ascending=False)
# Sorting our dataframe by mean, looking at either top 10 or top 3.
new_df = new_df.sort_values(by=['mean'], ascending = False)

new_df[0:10]
# Out:
#                count      mean
# job_title
# Data Position    282  0.189140
# Analyst         1892  0.166546
# Architect        828  0.161582
# Developer       5234  0.148490
# Director         146  0.147422
# Programmer       321  0.146484
# Engineer        4061  0.139889
# Administrator    898  0.137703
# Manager         1389  0.137032
# Consulting       592  0.127976

# %%
# Instantiating countvectorizer
count_vectorizer = CountVectorizer(stop_words = "english", min_df = 10)

# Cvec fit transform on column text in data
cvec_jobtext = count_vectorizer.fit_transform((jobs['text']))

# Transforming user profile column text
user_cvec = count_vectorizer.transform(profile_data_nolan['text'])
# Calculating cosine similarity between users profile and job text
cos_similar_user = map(lambda x: cosine_similarity(user_cvec, x), cvec_jobtext)

# Results are a list of our cosine similarity scores
results = list(cos_similar_user)

# Create a dataframe using our results and job_titles, then transposing
new_df = pd.DataFrame(data = [results, jobs['job_title']]).T
# Renaming column 0 to sim score, similar to our tfidf model, and 1 to job_title
new_df = new_df.rename(columns = {0: "sim_score", 1 : "job_title"})
# Column sim_score as float so that we can use groupby
new_df['sim_score'] = new_df['sim_score'].astype(float)
# Group by job_title, using count and mean to sort values
new_df = new_df.groupby('job_title').agg(['count', 'mean'])['sim_score'].sort_values('mean', ascending=False)
# Sorting our dataframe by mean, looking at either top 10 or top 3.
new_df = new_df.sort_values(by=['mean'], ascending = False)

new_df[0:10]
# Out:
#                count      mean
# job_title
# Data Position    282  0.201413
# Analyst         1892  0.156483
# Architect        828  0.145770
# Director         146  0.127460
# Developer       5234  0.122760
# Programmer       321  0.119675
# Administrator    898  0.111995
# Manager         1389  0.107826
# Engineer        4061  0.104696
# Consulting       592  0.102393
