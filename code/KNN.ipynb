# %% [markdown]
# # KNN Model

# %%
import pandas as pd
import numpy as np
import re
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from sklearn.neighbors import NearestNeighbors
from IPython.display import display_html

# %% [markdown]
# ## Jobs data

# %%
jobs = pd.read_csv('../data/job_postings.csv')
jobs = jobs.drop(columns=['date_added', 'organization', 'skills_len', 'job_type'])
jobs.fillna('', inplace=True)
jobs['text'] = jobs['job_description'] + ' ' + jobs['skills']

# %%
jobs
# Out:
#                                          job_description      job_title  \
# 0       an EDI Analyst with experience please read on...        Analyst
# 1      Informatica ETL DeveloperSt Petersburg FL Only...      Developer
# 2      This nationally recognized Microsoft Gold Part...        Manager
# 3       a .NET Developer with experience please read ...      Developer
# 4      Hatstand a global financial consultancy is see...      Developer
# ...                                                  ...            ...
# 16431    JPMorgan Chase & Co. (NYSE: JPM) is a leadin...      Developer
# 16432  Seeking Jr. Systems Administrators with experi...  Administrator
# 16433   a Senior Lead Devops Engineer with a desired ...      Developer
# 16434  Headquartered in downtown San Francisco CA we ...      Developer
# 16435   an AppSec or Hardware Security Engineer who h...       Engineer
#
#                       location  \
# 0      Northeast United States
# 1       Southern United States
# 2        Western United States
# 3      Northeast United States
# 4      Northeast United States
# ...                        ...
# 16431  Northeast United States
# 16432    Midwest United States
# 16433    Midwest United States
# 16434    Western United States
# 16435    Western United States
#
#                                                   skills  \
# 0                                 edi trustedlink as van
# 1      etl informatica b data exchange netezza oracle...
# 2      microsoft dynamics ax project manager - toront...
# 3                           c asp.net sql javascript mvc
# 4      java linux unix sdlc; multi-threaded or concur...
# ...                                                  ...
# 16431  .net architecture developer development git ht...
# 16432                            jr. linux administrator
# 16433   amazon web services linux bash ruby python agile
# 16434  javascript react.js golang startup ror iot ana...
# 16435  c .net java software application security hard...
#
#                                                     text
# 0       an EDI Analyst with experience please read on...
# 1      Informatica ETL DeveloperSt Petersburg FL Only...
# 2      This nationally recognized Microsoft Gold Part...
# 3       a .NET Developer with experience please read ...
# 4      Hatstand a global financial consultancy is see...
# ...                                                  ...
# 16431    JPMorgan Chase & Co. (NYSE: JPM) is a leadin...
# 16432  Seeking Jr. Systems Administrators with experi...
# 16433   a Senior Lead Devops Engineer with a desired ...
# 16434  Headquartered in downtown San Francisco CA we ...
# 16435   an AppSec or Hardware Security Engineer who h...
#
# [16436 rows x 5 columns]

# %% [markdown]
# ## User data

# %%
def gather_profile_data(file_path):
    profile_data = pd.read_csv(file_path)
    profile_data['text'] = profile_data['Titles'] + ' ' \
                            + profile_data['Skills'] + ' ' \
                            + profile_data['Summary'] + ' ' \
                            + profile_data['Education']
    return profile_data

# %%
# Reading in Zach's linkedin profile data.
profile_data_zach = gather_profile_data('../data/linkedin/test-output/Zach_LinkedInData_12-16-2020.csv')
profile_data_zach
# Out:
#             Name                                             Titles  \
# 0  Zachary Brown  Data Science Fellow, Python Developer, Health ...
#
#                                               Skills  \
# 0  Data Analysis, Python (Programming Language), ...
#
#                                              Summary  \
# 0  I bridge the gap between data and climate poli...
#
#                                        Education  \
# 0  Data Science Intensive, Bachelor's of Science
#
#                                       Certifications  \
# 0  Microsoft Certified: Azure Data Scientist Asso...
#
#                                                 text
# 0  Data Science Fellow, Python Developer, Health ...

# %%
# Reading in Nolan's linkedin profile data.
profile_data_nolan = gather_profile_data('../data/linkedin/test-output/Nolan_LinkedInData_12-16-2020.csv')
profile_data_nolan
# Out:
#            Name                        Titles  \
# 0  Nolan Arendt  Data Science Fellow, Painter
#
#                                               Skills  \
# 0  Data Science, Python, Data Analysis, Data Mana...
#
#                                              Summary  \
# 0  An innovative Data Scientist who is passionate...
#
#                                            Education  \
# 0  Bachelor's degree, Software Boot Camp Certificate
#
#                                                 text
# 0  Data Science Fellow, Painter Data Science, Pyt...

# %%
# Reading in Albert's linkedin profile data.
profile_data_albert = gather_profile_data('../data/linkedin/test-output/Albert_LinkedInData.csv')
profile_data_albert
# Out:
#             Name                                             Titles  \
# 0  Albert Frantz  Data Science Fellow, Assistant Teacher, Classr...
#
#                                               Skills  \
# 0  R, Python, Data Analysis, Econometrics, Projec...
#
#                                              Summary  \
# 0  I am a detail-oriented data scientist that use...
#
#                          Education  \
# 0  Bachelor of Arts - BA, nan, nan
#
#                                             Projects  \
# 0  Identifying the Relationship Between Bike Lane...
#
#                                       Certifications  \
# 0  Tableau 2020 A-Z: Hands-On Tableau Training fo...
#
#                                                 text
# 0  Data Science Fellow, Assistant Teacher, Classr...

# %% [markdown]
# ## Make recommendations

# %%
def get_recommendations(vectorizer, user_data):
    # Fit transform on text data
    tfidf_jobtext = tfidf_vectorizer.fit_transform(jobs['text'])

    # Transforming user profile text
    user_tfidf = tfidf_vectorizer.transform(user_data['text'])

    # Calculating KNN similarity between users profile and job text (top 100 most similar jobs)
    n_neighbors=75
    KNN = NearestNeighbors(n_neighbors=n_neighbors, p=2, metric='cosine', algorithm = 'brute')
    KNN.fit(tfidf_jobtext)
    NNs = KNN.kneighbors(user_tfidf, return_distance=True)

    # Finding indexs for n_neighbors most similar jobs
    index = list(NNs[1][0][1:]) # indexs for top jobs
    final_jobs = jobs.loc[index] 
    
    # Create a dataframe using our job title counts(top 10)
    pos_df = pd.DataFrame(final_jobs['job_title'].value_counts()[:10])
    
    # Renaming job_title
    pos_df['Job Count'] = pos_df['job_title']
    pos_df.drop(columns='job_title', inplace= True)
    
    # Creating column for percent of jobs matched
    pos_df['Job Match %'] = pos_df['Job Count']/n_neighbors
    
    return pos_df

# %% [markdown]
# ## Specific Recommendations

# %%
# Instantiating Tfidfvectorizer
tfidf_vectorizer = TfidfVectorizer(stop_words='english', ngram_range=(1,2))

# %%
# Calculate recommendations
nolans_recommendations = get_recommendations(tfidf_vectorizer, profile_data_nolan)
zachs_recommendations = get_recommendations(tfidf_vectorizer, profile_data_zach)
alberts_recommendations = get_recommendations(tfidf_vectorizer, profile_data_albert)

# %%
# Credit for notebook styling: https://blog.softhints.com/display-two-pandas-dataframes-side-by-side-jupyter-notebook/
df1_styler = zachs_recommendations.style.set_table_attributes("style='display:inline'").set_caption('Zach')
df2_styler = nolans_recommendations.style.set_table_attributes("style='display:inline'").set_caption('Nolan')
df3_styler = alberts_recommendations.style.set_table_attributes("style='display:inline'").set_caption('Albert')

space = "\xa0" * 10
display_html(df1_styler._repr_html_() + space + df2_styler._repr_html_() + space + df3_styler._repr_html_(), raw=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_17ff42a0_4349_11eb_882f_a4d18cca390a" style='display:inline'><caption>Zach</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Job Count</th>        <th class="col_heading level0 col1" >Job Match %</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_17ff42a0_4349_11eb_882f_a4d18cca390alevel0_row0" class="row_heading level0 row0" >Data Position</th>
#                         <td id="T_17ff42a0_4349_11eb_882f_a4d18cca390arow0_col0" class="data row0 col0" >31</td>
#                         <td id="T_17ff42a0_4349_11eb_882f_a4d18cca390arow0_col1" class="data row0 col1" >0.413333</td>
#             </tr>
#             <tr>
#                         <th id="T_17ff42a0_4349_11eb_882f_a4d18cca390alevel0_row1" class="row_heading level0 row1" >Analyst</th>
#                         <td id="T_17ff42a0_4349_11eb_882f_a4d18cca390arow1_col0" class="data row1 col0" >15</td>
#                         <td id="T_17ff42a0_4349_11eb_882f_a4d18cca390arow1_col1" class="data row1 col1" >0.200000</td>
#             </tr>
#             <tr>
#                         <th id="T_17ff42a0_4349_11eb_882f_a4d18cca390alevel0_row2" class="row_heading level0 row2" >Engineer</th>
#                         <td id="T_17ff42a0_4349_11eb_882f_a4d18cca390arow2_col0" class="data row2 col0" >9</td>
#                         <td id="T_17ff42a0_4349_11eb_882f_a4d18cca390arow2_col1" class="data row2 col1" >0.120000</td>
#             </tr>
#             <tr>
#                         <th id="T_17ff42a0_4349_11eb_882f_a4d18cca390alevel0_row3" class="row_heading level0 row3" >Architect</th>
#                         <td id="T_17ff42a0_4349_11eb_882f_a4d18cca390arow3_col0" class="data row3 col0" >8</td>
#                         <td id="T_17ff42a0_4349_11eb_882f_a4d18cca390arow3_col1" class="data row3 col1" >0.106667</td>
#             </tr>
#             <tr>
#                         <th id="T_17ff42a0_4349_11eb_882f_a4d18cca390alevel0_row4" class="row_heading level0 row4" >Developer</th>
#                         <td id="T_17ff42a0_4349_11eb_882f_a4d18cca390arow4_col0" class="data row4 col0" >7</td>
#                         <td id="T_17ff42a0_4349_11eb_882f_a4d18cca390arow4_col1" class="data row4 col1" >0.093333</td>
#             </tr>
#             <tr>
#                         <th id="T_17ff42a0_4349_11eb_882f_a4d18cca390alevel0_row5" class="row_heading level0 row5" >Programmer</th>
#                         <td id="T_17ff42a0_4349_11eb_882f_a4d18cca390arow5_col0" class="data row5 col0" >1</td>
#                         <td id="T_17ff42a0_4349_11eb_882f_a4d18cca390arow5_col1" class="data row5 col1" >0.013333</td>
#             </tr>
#             <tr>
#                         <th id="T_17ff42a0_4349_11eb_882f_a4d18cca390alevel0_row6" class="row_heading level0 row6" >Consulting</th>
#                         <td id="T_17ff42a0_4349_11eb_882f_a4d18cca390arow6_col0" class="data row6 col0" >1</td>
#                         <td id="T_17ff42a0_4349_11eb_882f_a4d18cca390arow6_col1" class="data row6 col1" >0.013333</td>
#             </tr>
#             <tr>
#                         <th id="T_17ff42a0_4349_11eb_882f_a4d18cca390alevel0_row7" class="row_heading level0 row7" >Director</th>
#                         <td id="T_17ff42a0_4349_11eb_882f_a4d18cca390arow7_col0" class="data row7 col0" >1</td>
#                         <td id="T_17ff42a0_4349_11eb_882f_a4d18cca390arow7_col1" class="data row7 col1" >0.013333</td>
#             </tr>
#             <tr>
#                         <th id="T_17ff42a0_4349_11eb_882f_a4d18cca390alevel0_row8" class="row_heading level0 row8" >Manager</th>
#                         <td id="T_17ff42a0_4349_11eb_882f_a4d18cca390arow8_col0" class="data row8 col0" >1</td>
#                         <td id="T_17ff42a0_4349_11eb_882f_a4d18cca390arow8_col1" class="data row8 col1" >0.013333</td>
#             </tr>
#     </tbody></table>          <style  type="text/css" >
# </style><table id="T_17ffdee0_4349_11eb_882f_a4d18cca390a" style='display:inline'><caption>Nolan</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Job Count</th>        <th class="col_heading level0 col1" >Job Match %</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_17ffdee0_4349_11eb_882f_a4d18cca390alevel0_row0" class="row_heading level0 row0" >Data Position</th>
#                         <td id="T_17ffdee0_4349_11eb_882f_a4d18cca390arow0_col0" class="data row0 col0" >26</td>
#                         <td id="T_17ffdee0_4349_11eb_882f_a4d18cca390arow0_col1" class="data row0 col1" >0.346667</td>
#             </tr>
#             <tr>
#                         <th id="T_17ffdee0_4349_11eb_882f_a4d18cca390alevel0_row1" class="row_heading level0 row1" >Developer</th>
#                         <td id="T_17ffdee0_4349_11eb_882f_a4d18cca390arow1_col0" class="data row1 col0" >17</td>
#                         <td id="T_17ffdee0_4349_11eb_882f_a4d18cca390arow1_col1" class="data row1 col1" >0.226667</td>
#             </tr>
#             <tr>
#                         <th id="T_17ffdee0_4349_11eb_882f_a4d18cca390alevel0_row2" class="row_heading level0 row2" >Engineer</th>
#                         <td id="T_17ffdee0_4349_11eb_882f_a4d18cca390arow2_col0" class="data row2 col0" >12</td>
#                         <td id="T_17ffdee0_4349_11eb_882f_a4d18cca390arow2_col1" class="data row2 col1" >0.160000</td>
#             </tr>
#             <tr>
#                         <th id="T_17ffdee0_4349_11eb_882f_a4d18cca390alevel0_row3" class="row_heading level0 row3" >Architect</th>
#                         <td id="T_17ffdee0_4349_11eb_882f_a4d18cca390arow3_col0" class="data row3 col0" >9</td>
#                         <td id="T_17ffdee0_4349_11eb_882f_a4d18cca390arow3_col1" class="data row3 col1" >0.120000</td>
#             </tr>
#             <tr>
#                         <th id="T_17ffdee0_4349_11eb_882f_a4d18cca390alevel0_row4" class="row_heading level0 row4" >Analyst</th>
#                         <td id="T_17ffdee0_4349_11eb_882f_a4d18cca390arow4_col0" class="data row4 col0" >5</td>
#                         <td id="T_17ffdee0_4349_11eb_882f_a4d18cca390arow4_col1" class="data row4 col1" >0.066667</td>
#             </tr>
#             <tr>
#                         <th id="T_17ffdee0_4349_11eb_882f_a4d18cca390alevel0_row5" class="row_heading level0 row5" >Consulting</th>
#                         <td id="T_17ffdee0_4349_11eb_882f_a4d18cca390arow5_col0" class="data row5 col0" >3</td>
#                         <td id="T_17ffdee0_4349_11eb_882f_a4d18cca390arow5_col1" class="data row5 col1" >0.040000</td>
#             </tr>
#             <tr>
#                         <th id="T_17ffdee0_4349_11eb_882f_a4d18cca390alevel0_row6" class="row_heading level0 row6" >Director</th>
#                         <td id="T_17ffdee0_4349_11eb_882f_a4d18cca390arow6_col0" class="data row6 col0" >1</td>
#                         <td id="T_17ffdee0_4349_11eb_882f_a4d18cca390arow6_col1" class="data row6 col1" >0.013333</td>
#             </tr>
#             <tr>
#                         <th id="T_17ffdee0_4349_11eb_882f_a4d18cca390alevel0_row7" class="row_heading level0 row7" >Manager</th>
#                         <td id="T_17ffdee0_4349_11eb_882f_a4d18cca390arow7_col0" class="data row7 col0" >1</td>
#                         <td id="T_17ffdee0_4349_11eb_882f_a4d18cca390arow7_col1" class="data row7 col1" >0.013333</td>
#             </tr>
#     </tbody></table>          <style  type="text/css" >
# </style><table id="T_18006cb6_4349_11eb_882f_a4d18cca390a" style='display:inline'><caption>Albert</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Job Count</th>        <th class="col_heading level0 col1" >Job Match %</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_18006cb6_4349_11eb_882f_a4d18cca390alevel0_row0" class="row_heading level0 row0" >Data Position</th>
#                         <td id
