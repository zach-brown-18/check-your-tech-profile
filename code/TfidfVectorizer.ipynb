# %% [markdown]
# # Tfidf Model

# %%
import pandas as pd
import numpy as np
import re
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from IPython.display import display_html

# %% [markdown]
# ## Jobs data

# %%
jobs = pd.read_csv('../data/job_postings.csv')
jobs = jobs.drop(columns=['date_added', 'organization', 'skills_len', 'job_type'])
jobs.fillna('', inplace=True)
jobs['text'] = jobs['job_description'] + ' ' + jobs['skills']

# %% [markdown]
# ## User data

# %%
def gather_profile_data(file_path):
    profile_data = pd.read_csv(file_path)
    profile_data['text'] = profile_data['Titles'] + ' ' \
                            + profile_data['Skills'] + ' ' \
                            + profile_data['Summary'] + ' ' \
                            + profile_data['Education']
    return profile_data

# %%
# Reading in Zach's linkedin profile data.
profile_data_zach = gather_profile_data('../data/linkedin/test-output/Zach_LinkedInData_12-16-2020.csv')
profile_data_zach
# Out:
#             Name                                             Titles  \
# 0  Zachary Brown  Data Science Fellow, Python Developer, Health ...
#
#                                               Skills  \
# 0  Data Analysis, Python (Programming Language), ...
#
#                                              Summary  \
# 0  I bridge the gap between data and climate poli...
#
#                                        Education  \
# 0  Data Science Intensive, Bachelor's of Science
#
#                                       Certifications  \
# 0  Microsoft Certified: Azure Data Scientist Asso...
#
#                                                 text
# 0  Data Science Fellow, Python Developer, Health ...

# %%
# Reading in Nolan's linkedin profile data.
profile_data_nolan = gather_profile_data('../data/linkedin/test-output/Nolan_LinkedInData_12-16-2020.csv')
profile_data_nolan
# Out:
#            Name                        Titles  \
# 0  Nolan Arendt  Data Science Fellow, Painter
#
#                                               Skills  \
# 0  Data Science, Python, Data Analysis, Data Mana...
#
#                                              Summary  \
# 0  An innovative Data Scientist who is passionate...
#
#                                            Education  \
# 0  Bachelor's degree, Software Boot Camp Certificate
#
#                                                 text
# 0  Data Science Fellow, Painter Data Science, Pyt...

# %%
# Reading in Albert's linkedin profile data.
profile_data_albert = gather_profile_data('../data/linkedin/test-output/Albert_LinkedInData.csv')
profile_data_albert
# Out:
#             Name                                             Titles  \
# 0  Albert Frantz  Data Science Fellow, Assistant Teacher, Classr...
#
#                                               Skills  \
# 0  R, Python, Data Analysis, Econometrics, Projec...
#
#                                              Summary  \
# 0  I am a detail-oriented data scientist that use...
#
#                          Education  \
# 0  Bachelor of Arts - BA, nan, nan
#
#                                             Projects  \
# 0  Identifying the Relationship Between Bike Lane...
#
#                                       Certifications  \
# 0  Tableau 2020 A-Z: Hands-On Tableau Training fo...
#
#                                                 text
# 0  Data Science Fellow, Assistant Teacher, Classr...

# %% [markdown]
# ## Make recommendations

# %%
def get_recommendations(vectorizer, user_data):
    # Fit transform on text data
    cvec_jobtext = vectorizer.fit_transform(jobs['text'])

    # Transforming user profile text
    user_cvec = vectorizer.transform(user_data['text'])

    # Calculating cosine similarity between users profile and job text
    cos_similar_user = map(lambda x: cosine_similarity(user_cvec, x), cvec_jobtext)

    # Results are a list of our cosine similarity scores
    results = list(cos_similar_user)

    # Create a dataframe using our results and job_titles
    new_df = pd.DataFrame(data = [results, jobs['job_title']]).T
    new_df = new_df.rename(columns = {0: "sim_score", 1 : "job_title"})

    # Column sim_score as float so that we can use groupby
    new_df['sim_score'] = new_df['sim_score'].astype(float)

    # Group by job_title, using count and mean to sort values
    new_df = new_df.groupby('job_title').agg(['count', 'mean'])['sim_score'].sort_values('mean', ascending=False)
    new_df = new_df.sort_values(by=['mean'], ascending = False)

    return new_df

# %%
# Instantiating countvectorizer
tfidf_vectorizer = TfidfVectorizer(stop_words = "english")

# %%
# Calculate similarity scores
zachs_recommendations = get_recommendations(tfidf_vectorizer, profile_data_zach)
nolans_recommendations = get_recommendations(tfidf_vectorizer, profile_data_nolan)
alberts_recommendations = get_recommendations(tfidf_vectorizer, profile_data_albert)

# %%
# Credit for notebook styling: https://blog.softhints.com/display-two-pandas-dataframes-side-by-side-jupyter-notebook/
df1_styler = zachs_recommendations.style.set_table_attributes("style='display:inline'").set_caption('Zach')
df2_styler = nolans_recommendations.style.set_table_attributes("style='display:inline'").set_caption('Nolan')
df3_styler = alberts_recommendations.style.set_table_attributes("style='display:inline'").set_caption('Albert')

space = "\xa0" * 10
display_html(df1_styler._repr_html_() + space + df2_styler._repr_html_() + space + df3_styler._repr_html_(), raw=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_68f25446_4348_11eb_a12c_a4d18cca390a" style='display:inline'><caption>Zach</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>    </tr>    <tr>        <th class="index_name level0" >job_title</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_68f25446_4348_11eb_a12c_a4d18cca390alevel0_row0" class="row_heading level0 row0" >Data Position</th>
#                         <td id="T_68f25446_4348_11eb_a12c_a4d18cca390arow0_col0" class="data row0 col0" >280</td>
#                         <td id="T_68f25446_4348_11eb_a12c_a4d18cca390arow0_col1" class="data row0 col1" >0.079419</td>
#             </tr>
#             <tr>
#                         <th id="T_68f25446_4348_11eb_a12c_a4d18cca390alevel0_row1" class="row_heading level0 row1" >Analyst</th>
#                         <td id="T_68f25446_4348_11eb_a12c_a4d18cca390arow1_col0" class="data row1 col0" >1884</td>
#                         <td id="T_68f25446_4348_11eb_a12c_a4d18cca390arow1_col1" class="data row1 col1" >0.053555</td>
#             </tr>
#             <tr>
#                         <th id="T_68f25446_4348_11eb_a12c_a4d18cca390alevel0_row2" class="row_heading level0 row2" >Architect</th>
#                         <td id="T_68f25446_4348_11eb_a12c_a4d18cca390arow2_col0" class="data row2 col0" >823</td>
#                         <td id="T_68f25446_4348_11eb_a12c_a4d18cca390arow2_col1" class="data row2 col1" >0.047552</td>
#             </tr>
#             <tr>
#                         <th id="T_68f25446_4348_11eb_a12c_a4d18cca390alevel0_row3" class="row_heading level0 row3" >Director</th>
#                         <td id="T_68f25446_4348_11eb_a12c_a4d18cca390arow3_col0" class="data row3 col0" >144</td>
#                         <td id="T_68f25446_4348_11eb_a12c_a4d18cca390arow3_col1" class="data row3 col1" >0.038748</td>
#             </tr>
#             <tr>
#                         <th id="T_68f25446_4348_11eb_a12c_a4d18cca390alevel0_row4" class="row_heading level0 row4" >Developer</th>
#                         <td id="T_68f25446_4348_11eb_a12c_a4d18cca390arow4_col0" class="data row4 col0" >5181</td>
#                         <td id="T_68f25446_4348_11eb_a12c_a4d18cca390arow4_col1" class="data row4 col1" >0.037282</td>
#             </tr>
#             <tr>
#                         <th id="T_68f25446_4348_11eb_a12c_a4d18cca390alevel0_row5" class="row_heading level0 row5" >Programmer</th>
#                         <td id="T_68f25446_4348_11eb_a12c_a4d18cca390arow5_col0" class="data row5 col0" >321</td>
#                         <td id="T_68f25446_4348_11eb_a12c_a4d18cca390arow5_col1" class="data row5 col1" >0.036279</td>
#             </tr>
#             <tr>
#                         <th id="T_68f25446_4348_11eb_a12c_a4d18cca390alevel0_row6" class="row_heading level0 row6" >Engineer</th>
#                         <td id="T_68f25446_4348_11eb_a12c_a4d18cca390arow6_col0" class="data row6 col0" >4045</td>
#                         <td id="T_68f25446_4348_11eb_a12c_a4d18cca390arow6_col1" class="data row6 col1" >0.032124</td>
#             </tr>
#             <tr>
#                         <th id="T_68f25446_4348_11eb_a12c_a4d18cca390alevel0_row7" class="row_heading level0 row7" >Administrator</th>
#                         <td id="T_68f25446_4348_11eb_a12c_a4d18cca390arow7_col0" class="data row7 col0" >896</td>
#                         <td id="T_68f25446_4348_11eb_a12c_a4d18cca390arow7_col1" class="data row7 col1" >0.028264</td>
#             </tr>
#             <tr>
#                         <th id="T_68f25446_4348_11eb_a12c_a4d18cca390alevel0_row8" class="row_heading level0 row8" >Manager</th>
#                         <td id="T_68f25446_4348_11eb_a12c_a4d18cca390arow8_col0" class="data row8 col0" >1379</td>
#                         <td id="T_68f25446_4348_11eb_a12c_a4d18cca390arow8_col1" class="data row8 col1" >0.026298</td>
#             </tr>
#             <tr>
#                         <th id="T_68f25446_4348_11eb_a12c_a4d18cca390alevel0_row9" class="row_heading level0 row9" >Consulting</th>
#                         <td id="T_68f25446_4348_11eb_a12c_a4d18cca390arow9_col0" class="data row9 col0" >578</td>
#                         <td id="T_68f25446_4348_11eb_a12c_a4d18cca390arow9_col1" class="data row9 col1" >0.024505</td>
#             </tr>
#             <tr>
#                         <th id="T_68f25446_4348_11eb_a12c_a4d18cca390alevel0_row10" class="row_heading level0 row10" >Support</th>
#                         <td id="T_68f25446_4348_11eb_a12c_a4d18cca390arow10_col0" class="data row10 col0" >343</td>
#                         <td id="T_68f25446_4348_11eb_a12c_a4d18cca390arow10_col1" class="data row10 col1" >0.024371</td>
#             </tr>
#             <tr>
#                         <th id="T_68f25446_4348_11eb_a12c_a4d18cca390alevel0_row11" class="row_heading level0 row11" >Designer</th>
#                         <td id="T_68f25446_4348_11eb_a12c_a4d18cca390arow11_col0" class="data row11 col0" >220</td>
#                         <td id="T_68f25446_4348_11eb_a12c_a4d18cca390arow11_col1" class="data row11 col1" >0.019223</td>
#             </tr>
#             <tr>
#                         <th id="T_68f25446_4348_11eb_a12c_a4d18cca390alevel0_row12" class="row_heading level0 row12" >Technician</th>
#                         <td id="T_68f25446_4348_11eb_a12c_a4d18cca390arow12_col0" class="data row12 col0" >342</td>
#                         <td id="T_68f25446_4348_11eb_a12c_a4d18cca390arow12_col1" class="data row12 col1" >0.017995</td>
#             </tr>
#     </tbody></table>          <style  type="text/css" >
# </style><table id="T_68f3194e_4348_11eb_a12c_a4d18cca390a" style='display:inline'><caption>Nolan</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>    </tr>    <tr>        <th class="index_name level0" >job_title</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_68f3194e_4348_11eb_a12c_a4d18cca390alevel0_row0" class="row_heading level0 row0" >Data Position</th>
#                         <td id="T_68f3194e_4348_11eb_a12c_a4d18cca390arow0_col0" class="data row0 col0" >280</td>
#                         <td id="T_68f3194e_4348_11eb_a12c_a4d18cca390arow0_col1" class="data row0 col1" >0.086699</td>
#             </tr>
#             <tr>
#                         <th id="T_68f3194e_4348_11eb_a12c_a4d18cca390alevel0_row1" class="row_heading level0 row1" >Analyst</th>
#                         <td id="T_68f3194e_4348_11eb_a12c_a4d18cca390arow1_col0" class="data row1 col0" >1884</td>
#                         <td id="T_68f3194e_4348_11eb_a12c_a4d18cca390arow1_col1" class="data row1 col1" >0.057694</td>
#             </tr>
#             <tr>
#                         <th id="T_68f3194e_4348_11eb_a12c_a4d18cca390alevel0_row2" class="row_heading level0 row2" >Architect</th>
#                         <td id="T_68f3194e_4348_11eb_a12c_a4d18cca390arow2_col0" class="data row2 col0" >823</td>
#                         <td id="T_68f3194e_4348_11eb_a12c_a4d18cca390arow2_col1" class="data row2 col1" >0.053962</td>
#             </tr>
#             <tr>
#                         <th id="T_68f3194e_4348_11eb_a12c_a4d18cca390alevel0_row3" class="row_heading level0 row3" >Developer</th>
#                         <td id="T_68f3194e_4348_11eb_a12c_a4d18cca390arow3_col0" class="data row3 col0" >5181</td>
#                         <td id="T_68f3194e_4348_11eb_a12c_a4d18cca390arow3_col1" class="data row3 col1" >0.050618</td>
#             </tr>
#             <tr>
#                         <th id="T_68f3194e_4348_11eb_a12c_a4d18cca390alevel0_row4" class="row_heading level0 row4" >Director</th>
#                         <td id="T_68f3194e_4348_11eb_a12c_a4d18cca390arow4_col0" class="data row4
